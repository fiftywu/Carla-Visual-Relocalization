# %%
import os
import pickle
import numpy as np
from sqlite3 import dbapi2 as sqlite
import cv2
from BOW.imagesearch.vocabulary import Vocabulary, extract_feature
from BOW.imagesearch import imagesearch


def get_img_paths(training_path):
    #  根据图像数据文件夹路径获取所有图片路径
    training_names = os.listdir(training_path)
    img_paths = []  # 所有图片路径
    for name in training_names:
        img_path = os.path.join(training_path, name)
        img_paths.append(img_path)
    return img_paths

class ImageRetrieval():
    def __init__(self):
        self.feature = 'orb'
        self.base_dir = 'D:\\MyFiles\\SceneTransformation\\Relocalization_all\\Town02\\W000_P100_V000_P000'
        self.training_path = os.path.join(self.base_dir, 'RGB')  # 训练样本文件夹路径

        self.vocabulary_path = os.path.join(self.base_dir, 'vocabulary.pkl')
        self.vocabulary_name = 'swallow'
        self.database_name = 'ImaAdd.db'
        self.img_paths = get_img_paths(self.training_path)
        
#         self.all_img_paths = self.img_paths

        self.all_img_paths = get_img_paths(self.training_path) + \
                             get_img_paths(os.path.join('D:\\MyFiles\\SceneTransformation\\Relocalization_all\\Town02\\W000_P100_V050_P200', 'RGB')) + \
                             get_img_paths(os.path.join('D:\\MyFiles\\SceneTransformation\\Relocalization_all\\Town02\\W000_P100_V075_P300', 'RGB')) + \
                             get_img_paths(os.path.join('D:\\MyFiles\\SceneTransformation\\Relocalization_all\\Town02\\W000_P100_V075_P300', 'ProcessedImages')) + \
                             get_img_paths(os.path.join('D:\\MyFiles\\SceneTransformation\\Relocalization_all\\Town02\\W000_P100_V075_P300', 'output'))

        self.gen_vocabulary(word_num=50)

    def gen_vocabulary(self, word_num=100, subsampling=10):
        # subsampling: 训练数据的下采样（subsampling）可用于加速
        voc = Vocabulary(self.vocabulary_name, self.feature)
        voc.train(self.img_paths, word_num, subsampling)
        # 保存词汇
        with open(self.vocabulary_path, 'wb') as f:
            pickle.dump(voc, f)
        print('vocabulary generated:', voc.name, 'words_num', voc.nbr_words, 'feature:', voc.feature)

    def commit_database(self):
        # 载入词汇
        with open(self.vocabulary_path, 'rb') as f:
            voc = pickle.load(f)

        # 创建索引
        indx = imagesearch.Indexer(self.database_name, voc)
        indx.create_tables()
        # 遍历所有的图像，并将它们的特征投影到词汇上
        for path in self.all_img_paths:
            des = extract_feature(path, self.feature)
            indx.add_to_index(path, des)
        # 提交到数据库
        indx.db_commit()

    def image_query(self, query_image_path, nbr_results=5, show_plot=False, src_return=False):
        # nbr_results 结果图像数
        # 载入词汇
        with open(self.vocabulary_path, 'rb') as f:
            voc = pickle.load(f)
        src = imagesearch.Searcher(self.database_name, voc)
        # 遍历所有的图像，并将它们的特征投影到词汇上
        # iw = voc.project(descr)
        # print('当前图像单词词频（直方图）：'), print(iw)
        # print('候选图像列表：'), print(src.candidates_from_histogram(iw)[:10])  # 获取具有相似单词的图像列表
        # print('匹配结果：')
        res_info = src.query(query_image_path)[:nbr_results]  # ((distance, id),())
        res_id = [w[1] for w in res_info]
        if show_plot:
            imagesearch.plot_results(src, res_id)

        res = []
        for item in res_info:
            index = item[1]-1
            path = self.all_img_paths[index]
            score = item[0]
            tmp = [index, path, score]
            res.append(tmp)
        if src_return:
            return res, src
        else:
            return res


def get_frame_info():
    # 统一不同动态设置下的图像及其位置坐标
    dir1 = './Town02/W000_P100_V000_P000'
    dir2 = './Town02/W000_P100_V050_P200'
    dir3 = './Town02/W000_P100_V075_P300'
    static_list = os.listdir(os.path.join(dir1, 'RGB'))
    dynamic1_list = os.listdir(os.path.join(dir2, 'RGB'))
    dynamic2_list = os.listdir(os.path.join(dir3, 'RGB'))  # frame 最多

    for frame in dynamic2_list:
        if frame not in dynamic1_list or frame not in static_list:
            for dir_ in [dir1, dir2, dir3]:
                for parse in ['Depth', 'RGB', 'SemanticSegmentation']:
                    try:
                        os.remove(os.path.join(dir_, parse, frame))
                    except:
                        pass

    frame_img = os.listdir(os.path.join(dir1, 'RGB'))
    trajectory = np.loadtxt(os.path.join(dir3, 'Trajectory.txt'))
    frame_pos = []
    for path in frame_img:
        frame_num = int(path[-10:-4])
        frame_pos.append(trajectory[frame_num,[1,2]])
    return frame_img, frame_pos


def get_topN_from_training(res, training_parse, topN=5):
    # res[0]: [index, path, score]
    save_res = []
    for i in range(len(res)):
        index = res[i][0]
        path = res[i][1]
        score = res[i][2]
        if training_parse in path:
            save_res.append(res[i])
    res_filter = save_res[:topN]
    return res_filter

# %%
ImgRetrieval = ImageRetrieval()
ImgRetrieval.commit_database()
# Out:
# vocabulary generated: swallow words_num 50 feature: orb
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000030.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000040.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000050.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000060.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000070.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000080.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000090.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000100.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000110.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000120.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000130.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000140.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000150.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000160.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000170.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000180.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000190.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000200.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000210.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000220.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000230.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000240.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000250.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000260.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000270.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000280.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000290.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000300.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000310.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000320.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000330.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000340.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000350.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000360.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000370.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000380.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000390.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000400.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000410.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000420.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000430.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000440.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000450.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000460.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000470.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000480.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000490.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000500.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000510.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000520.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000530.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000540.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000550.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000560.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000570.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000580.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000590.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000600.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000610.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000620.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000630.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000640.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000650.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000660.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000670.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000680.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000690.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000700.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000710.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000720.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000730.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000740.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000750.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000760.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000770.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000780.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000790.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000800.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000810.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000820.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000830.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000840.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000850.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000860.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000870.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000880.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000890.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000900.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000910.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000920.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000930.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000940.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000950.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000960.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000970.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000980.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\000990.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001000.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001010.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001020.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001030.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001040.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001050.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001060.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001070.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001080.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001090.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001100.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001110.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001120.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001130.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001140.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001150.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001160.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001170.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001180.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001190.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001200.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001210.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001220.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001230.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001240.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001250.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001260.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001270.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001280.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001290.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001300.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001310.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001320.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001330.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001340.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001350.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001360.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001370.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001380.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001390.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001400.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001410.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001420.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001430.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001440.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001450.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001460.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001470.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001480.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001490.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001500.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001510.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001520.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001530.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001540.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001550.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001560.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001570.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001580.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001590.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001610.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001660.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001670.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001680.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001700.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V000_P000\RGB\001710.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000030.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000040.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000050.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000060.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000070.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000080.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000090.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000100.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000110.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000120.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000130.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000140.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000150.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000160.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000170.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000180.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000190.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000200.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000210.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000220.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000230.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000240.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000250.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000260.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000270.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000280.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000290.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000300.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000310.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000320.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000330.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000340.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000350.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000360.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000370.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000380.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000390.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000400.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000410.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000420.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000430.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000440.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000450.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000460.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000470.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000480.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000490.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\000500.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V050_P200\RGB\
png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001340.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001350.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001360.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001370.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001380.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001390.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001400.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001410.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001420.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001430.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001440.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001450.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001460.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001470.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001480.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001490.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001500.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001510.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001520.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001530.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001540.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001550.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001560.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001570.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001580.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001590.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001610.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001660.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001670.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001680.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001700.png
# indexing D:\MyFiles\SceneTransformation\Relocalization_all\Town02\W000_P100_V075_P300\output\001710.png

# %%
frame_img, frame_pos = get_frame_info()
query_dir = 'D:\\MyFiles\\SceneTransformation\\Relocalization_all\\Town02\\W000_P100_V075_P300'
img_names = os.listdir(os.path.join(query_dir, 'RGB'))  # 训练样本文件夹路径
# img_names = os.listdir(os.path.join(query_dir, 'RGB'))  # 训练样本文件夹路径

error_rate_save = []
for i in range(len(img_names)):
    query_image_path = os.path.join(query_dir, 'output', img_names[i])
    ind = frame_img.index(query_image_path[-10:])
    query_image_pos = frame_pos[ind]
    res, src = ImgRetrieval.image_query(query_image_path, nbr_results=5*len(img_names), src_return=True)
    res_filter = get_topN_from_training(res, training_parse='W000_P100_V000_P000', topN=5)
    # imagesearch.plot_results(src, [w[0]+1 for w in res_filter])  # 此处，数据库序号从1开始，故1

    if len(res_filter):
        pos = np.array([frame_pos[w[0]] for w in res_filter])
        error_rate = np.abs((pos[0][0]-query_image_pos[0])/(query_image_pos[0]+1e-3))*0.5 + \
                     np.abs((pos[0][1]-query_image_pos[1])/(query_image_pos[1]+1e-3))*0.5
        error_rate_save.append(error_rate)
#         print(error_rate)
    else:
        print('no matched')
        error_rate = 1
        error_rate_save.append(error_rate)
print('mean_error', np.mean(error_rate_save), 'acc', np.sum(np.array(error_rate_save) < 0.01)/len(error_rate_save))
# Out:
# mean_error 0.03853849000864052 acc 0.6012269938650306

# %%
print('mean_error', np.mean(error_rate_save), 'acc', np.sum(np.array(error_rate_save) < 0.05)/len(error_rate_save))
# Out:
# mean_error 0.03853849000864052 acc 0.803680981595092

# %% [markdown]
# # center_nums = 100

# %%
W000_P100_V000_P000
mean_error 0.0 acc 1.0

W000_P100_V050_P200
mean_error 0.002447752512391457 acc 0.9815950920245399
W000_P100_V050_P200_ Dynamic2static
mean_error 0.0033546565474536346 acc 0.9754601226993865

W000_P100_V075_P300
mean_error 0.06825475897850955 acc 0.5828220858895705 （0.01）
mean_error 0.06825475897850955 acc 0.7668711656441718 （0.05）

W000_P100_V075_P300_ProcessedImages
mean_error 0.029741254932275148 acc 0.9325153374233128 （0.01）
mean_error 0.029741254932275148 acc 0.9570552147239264（0.05）

W000_P100_V075_P300_Emptycities
mean_error 0.0037736515980072035 acc 0.8834355828220859 (0.01)
mean_error 0.0037736515980072035 acc 1.0 (0.05)

# %% [markdown]
# # center_nums = 50

# %%
W000_P100_V075_P300
mean_error 0.10399403802791685 acc 0.4294478527607362 （0.01）
mean_error 0.10399403802791685 acc 0.5153374233128835 （0.05）

W000_P100_V075_P300_ProcessedImages
mean_error 0.027430995256036823 acc 0.7791411042944786
mean_error 0.027430995256036823 acc 0.8773006134969326

W000_P100_V075_P300_Emptycities
mean_error 0.03853849000864052 acc 0.6012269938650306
mean_error 0.03853849000864052 acc 0.803680981595092
